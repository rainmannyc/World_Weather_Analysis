# %%
from citipy import citipy
from config import weather_api_key
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import gmaps

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903698, 25.92677388, 26.62249167, -59.98487384, 37.36971269]
y = [-67.59744219, 11.09532225, 74.16233102, -76.13176677, -61.13374882]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903698 -67.59744219
# 25.92677388 11.09532225
# 26.62249167 74.16233102
# -59.98487384 -76.13176677
# 37.36971269 -61.13374882

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):
# Run an API request for each of the cities.
    try:
            # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
    # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
     
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | paracuru
# Processing Record 7 of Set 1 | bull savanna
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | gharghoda
# Processing Record 13 of Set 1 | maxixe
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | axim
# Processing Record 16 of Set 1 | camacha
# Processing Record 17 of Set 1 | tres lagoas
# Processing Record 18 of Set 1 | lithakia
# Processing Record 19 of Set 1 | arlit
# Processing Record 20 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 21 of Set 1 | belushya guba
# Processing Record 22 of Set 1 | jiaozuo
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | kuusankoski
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | lata
# Processing Record 31 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 32 of Set 1 | mys shmidta
# Processing Record 33 of Set 1 | wahiawa
# Processing Record 34 of Set 1 | kirakira
# Processing Record 35 of Set 1 | santa cruz de la palma
# Processing Record 36 of Set 1 | anadyr
# Processing Record 37 of Set 1 | dolores
# Processing Record 38 of Set 1 | honiara
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 41 of Set 1 | amderma
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | haines junction
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | filadelfia
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | neiafu
# Processing Record 49 of Set 1 | kamenka
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | paragominas
# Processing Record 3 of Set 2 | jiazi
# Processing Record 4 of Set 2 | nome
# City not found. Skipping...
# Processing Record 5 of Set 2 | taolanaro
# Processing Record 6 of Set 2 | olean
# Processing Record 7 of Set 2 | bira
# Processing Record 8 of Set 2 | terra santa
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | cravo norte
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | edson
# Processing Record 15 of Set 2 | sao joao da barra
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | morecambe
# City not found. Skipping...
# Processing Record 19 of Set 2 | samusu
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | bonthe
# Processing Record 24 of Set 2 | port hardy
# Processing Record 25 of Set 2 | korla
# Processing Record 26 of Set 2 | iqaluit
# City not found. Skipping...
# Processing Record 27 of Set 2 | yomitan
# Processing Record 28 of Set 2 | samfya
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | ken caryl
# Processing Record 31 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 32 of Set 2 | vaitupu
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | santo domingo
# Processing Record 35 of Set 2 | vanavara
# Processing Record 36 of Set 2 | lazo
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | high level
# Processing Record 41 of Set 2 | thinadhoo
# Processing Record 42 of Set 2 | purworejo
# Processing Record 43 of Set 2 | saravan
# Processing Record 44 of Set 2 | cervo
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | kraslava
# City not found. Skipping...
# Processing Record 49 of Set 2 | nizhneyansk
# Processing Record 50 of Set 2 | boyuibe
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | puerto escondido
# Processing Record 3 of Set 3 | narsaq
# Processing Record 4 of Set 3 | destin
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | filingue
# Processing Record 8 of Set 3 | novonukutskiy
# Processing Record 9 of Set 3 | messina
# Processing Record 10 of Set 3 | mareeba
# Processing Record 11 of Set 3 | uniontown
# Processing Record 12 of Set 3 | udachnyy
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | altamont
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | dwarka
# Processing Record 20 of Set 3 | ambon
# City not found. Skipping...
# Processing Record 21 of Set 3 | tsihombe
# Processing Record 22 of Set 3 | key west
# City not found. Skipping...
# Processing Record 23 of Set 3 | lolua
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | beringovskiy
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | miri
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | garango
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | isla mujeres
# Processing Record 33 of Set 3 | sao raimundo nonato
# Processing Record 34 of Set 3 | brigantine
# Processing Record 35 of Set 3 | richards bay
# Processing Record 36 of Set 3 | baruun-urt
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | mingguang
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | piet retief
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | warrnambool
# Processing Record 46 of Set 3 | chantada
# Processing Record 47 of Set 3 | kaohsiung
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | ulladulla
# Processing Record 50 of Set 3 | abingdon
# City not found. Skipping...
# Processing Record 1 of Set 4 | grand river south east
# Processing Record 2 of Set 4 | manga
# City not found. Skipping...
# Processing Record 3 of Set 4 | tarudant
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | mala
# Processing Record 6 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 7 of Set 4 | sentyabrskiy
# Processing Record 8 of Set 4 | buta
# Processing Record 9 of Set 4 | alappuzha
# Processing Record 10 of Set 4 | verkhnetulomskiy
# Processing Record 11 of Set 4 | iquitos
# Processing Record 12 of Set 4 | comarapa
# Processing Record 13 of Set 4 | greensburg
# Processing Record 14 of Set 4 | laguna
# Processing Record 15 of Set 4 | portland
# Processing Record 16 of Set 4 | webuye
# Processing Record 17 of Set 4 | japura
# City not found. Skipping...
# Processing Record 18 of Set 4 | skagastrond
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | kaeo
# City not found. Skipping...
# Processing Record 22 of Set 4 | tabarqah
# Processing Record 23 of Set 4 | great falls
# Processing Record 24 of Set 4 | nikolayevka
# Processing Record 25 of Set 4 | chakradharpur
# Processing Record 26 of Set 4 | george town
# Processing Record 27 of Set 4 | beloha
# Processing Record 28 of Set 4 | grand forks
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | sur
# Processing Record 31 of Set 4 | juba
# Processing Record 32 of Set 4 | laiwu
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | margate
# Processing Record 35 of Set 4 | tiksi
# City not found. Skipping...
# Processing Record 36 of Set 4 | louisbourg
# Processing Record 37 of Set 4 | mulege
# Processing Record 38 of Set 4 | chissamba
# Processing Record 39 of Set 4 | krasnoselkup
# Processing Record 40 of Set 4 | sabha
# Processing Record 41 of Set 4 | gigmoto
# Processing Record 42 of Set 4 | boa vista
# Processing Record 43 of Set 4 | prince rupert
# Processing Record 44 of Set 4 | senno
# Processing Record 45 of Set 4 | machali
# Processing Record 46 of Set 4 | dimapur
# City not found. Skipping...
# Processing Record 47 of Set 4 | illoqqortoormiut
# Processing Record 48 of Set 4 | wanning
# Processing Record 49 of Set 4 | lakes entrance
# Processing Record 50 of Set 4 | markova
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | mentougou
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | hualmay
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | qeshm
# Processing Record 7 of Set 5 | ahuimanu
# Processing Record 8 of Set 5 | omboue
# Processing Record 9 of Set 5 | manaure
# Processing Record 10 of Set 5 | chibombo
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | tilichiki
# Processing Record 13 of Set 5 | ormara
# Processing Record 14 of Set 5 | tamara
# Processing Record 15 of Set 5 | porto novo
# Processing Record 16 of Set 5 | erzin
# Processing Record 17 of Set 5 | whittlesea
# Processing Record 18 of Set 5 | tual
# Processing Record 19 of Set 5 | guiyang
# Processing Record 20 of Set 5 | vao
# Processing Record 21 of Set 5 | awbari
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | mezokovesd
# Processing Record 24 of Set 5 | yerbogachen
# Processing Record 25 of Set 5 | amos
# Processing Record 26 of Set 5 | itaituba
# Processing Record 27 of Set 5 | chapais
# Processing Record 28 of Set 5 | champerico
# Processing Record 29 of Set 5 | evensk
# City not found. Skipping...
# Processing Record 30 of Set 5 | barentsburg
# Processing Record 31 of Set 5 | jiwani
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | mosquera
# Processing Record 34 of Set 5 | kawalu
# Processing Record 35 of Set 5 | tashla
# City not found. Skipping...
# Processing Record 36 of Set 5 | safaqis
# Processing Record 37 of Set 5 | geraldton
# City not found. Skipping...
# Processing Record 38 of Set 5 | marcona
# Processing Record 39 of Set 5 | florianopolis
# Processing Record 40 of Set 5 | yanji
# Processing Record 41 of Set 5 | tynda
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | venado tuerto
# Processing Record 44 of Set 5 | ayagoz
# City not found. Skipping...
# Processing Record 45 of Set 5 | karkaralinsk
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | mahanoro
# Processing Record 49 of Set 5 | dongsheng
# Processing Record 50 of Set 5 | qesarya
# Processing Record 1 of Set 6 | sao filipe
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | kangaatsiaq
# Processing Record 4 of Set 6 | baykit
# Processing Record 5 of Set 6 | barcelos
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | bageshwar
# Processing Record 8 of Set 6 | mogadishu
# Processing Record 9 of Set 6 | ixtapa
# Processing Record 10 of Set 6 | kontagora
# City not found. Skipping...
# Processing Record 11 of Set 6 | sorvag
# Processing Record 12 of Set 6 | barra patuca
# Processing Record 13 of Set 6 | nouadhibou
# Processing Record 14 of Set 6 | mattru
# Processing Record 15 of Set 6 | chokurdakh
# Processing Record 16 of Set 6 | darhan
# Processing Record 17 of Set 6 | vanderbijlpark
# Processing Record 18 of Set 6 | izhma
# Processing Record 19 of Set 6 | yelahanka
# Processing Record 20 of Set 6 | tromso
# Processing Record 21 of Set 6 | donskoye
# City not found. Skipping...
# Processing Record 22 of Set 6 | umzimvubu
# Processing Record 23 of Set 6 | san juan
# City not found. Skipping...
# Processing Record 24 of Set 6 | saleaula
# Processing Record 25 of Set 6 | tsiroanomandidy
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | banda aceh
# Processing Record 28 of Set 6 | vladyslavivka
# Processing Record 29 of Set 6 | dauriya
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | shimoda
# Processing Record 32 of Set 6 | nouna
# Processing Record 33 of Set 6 | husavik
# Processing Record 34 of Set 6 | inuvik
# Processing Record 35 of Set 6 | zhanaozen
# Processing Record 36 of Set 6 | winona
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | pocone
# Processing Record 39 of Set 6 | svetlogorsk
# Processing Record 40 of Set 6 | los llanos de aridane
# Processing Record 41 of Set 6 | copiapo
# Processing Record 42 of Set 6 | olden
# Processing Record 43 of Set 6 | gerede
# Processing Record 44 of Set 6 | saint-francois
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | kristiansund
# Processing Record 47 of Set 6 | scottsbluff
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | todos santos
# Processing Record 50 of Set 6 | farragut
# Processing Record 1 of Set 7 | te anau
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | kaele
# Processing Record 4 of Set 7 | khash
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | turukhansk
# Processing Record 7 of Set 7 | mersing
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | mecca
# Processing Record 10 of Set 7 | teguise
# Processing Record 11 of Set 7 | ganzhou
# Processing Record 12 of Set 7 | hovd
# Processing Record 13 of Set 7 | lerwick
# Processing Record 14 of Set 7 | brazzaville
# Processing Record 15 of Set 7 | shahr-e babak
# Processing Record 16 of Set 7 | bairiki
# Processing Record 17 of Set 7 | la pintada
# Processing Record 18 of Set 7 | morrope
# Processing Record 19 of Set 7 | bathsheba
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | mali
# Processing Record 22 of Set 7 | nioro
# Processing Record 23 of Set 7 | mastic beach
# Processing Record 24 of Set 7 | esperantina
# Processing Record 25 of Set 7 | vysokogornyy
# Processing Record 26 of Set 7 | sault sainte marie
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | zyryanka
# Processing Record 29 of Set 7 | ipixuna
# Processing Record 30 of Set 7 | vila velha
# City not found. Skipping...
# Processing Record 31 of Set 7 | ozgon
# Processing Record 32 of Set 7 | sao felix do xingu
# Processing Record 33 of Set 7 | balikpapan
# Processing Record 34 of Set 7 | sola
# Processing Record 35 of Set 7 | ekhabi
# Processing Record 36 of Set 7 | veinticinco de mayo
# Processing Record 37 of Set 7 | port-gentil
# Processing Record 38 of Set 7 | lake city
# Processing Record 39 of Set 7 | ilhabela
# Processing Record 40 of Set 7 | shenjiamen
# Processing Record 41 of Set 7 | asau
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | taltal
# Processing Record 44 of Set 7 | balabac
# Processing Record 45 of Set 7 | walvis bay
# Processing Record 46 of Set 7 | bud
# Processing Record 47 of Set 7 | suriapet
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | tura
# Processing Record 50 of Set 7 | seoul
# City not found. Skipping...
# Processing Record 1 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 8 | palabuhanratu
# Processing Record 3 of Set 8 | natal
# City not found. Skipping...
# Processing Record 4 of Set 8 | babanusah
# Processing Record 5 of Set 8 | antalya
# Processing Record 6 of Set 8 | camacupa
# Processing Record 7 of Set 8 | tuy hoa
# Processing Record 8 of Set 8 | narasannapeta
# Processing Record 9 of Set 8 | nalut
# Processing Record 10 of Set 8 | elko
# Processing Record 11 of Set 8 | sarangani
# Processing Record 12 of Set 8 | imbituba
# Processing Record 13 of Set 8 | broome
# Processing Record 14 of Set 8 | dingle
# Processing Record 15 of Set 8 | khandyga
# Processing Record 16 of Set 8 | lahij
# Processing Record 17 of Set 8 | mezhova
# Processing Record 18 of Set 8 | coihaique
# Processing Record 19 of Set 8 | beboto
# Processing Record 20 of Set 8 | marrakesh
# Processing Record 21 of Set 8 | guaruja
# Processing Record 22 of Set 8 | pringsewu
# Processing Record 23 of Set 8 | tessalit
# Processing Record 24 of Set 8 | ashland
# Processing Record 25 of Set 8 | placido de castro
# Processing Record 26 of Set 8 | lodja
# Processing Record 27 of Set 8 | krasnyy yar
# Processing Record 28 of Set 8 | mangan
# Processing Record 29 of Set 8 | tocopilla
# Processing Record 30 of Set 8 | vila franca do campo
# City not found. Skipping...
# Processing Record 31 of Set 8 | wulanhaote
# Processing Record 32 of Set 8 | sibolga
# Processing Record 33 of Set 8 | grootfontein
# Processing Record 34 of Set 8 | bonavista
# Processing Record 35 of Set 8 | gambela
# Processing Record 36 of Set 8 | furstenwalde
# Processing Record 37 of Set 8 | sorland
# City not found. Skipping...
# Processing Record 38 of Set 8 | jahrom
# Processing Record 39 of Set 8 | panalingaan
# Processing Record 40 of Set 8 | suez
# Processing Record 41 of Set 8 | svetlyy
# Processing Record 42 of Set 8 | bichura
# Processing Record 43 of Set 8 | rabo de peixe
# Processing Record 44 of Set 8 | pritzwalk
# Processing Record 45 of Set 8 | labuhan
# Processing Record 46 of Set 8 | okato
# Processing Record 47 of Set 8 | olinda
# Processing Record 48 of Set 8 | talwandi bhai
# Processing Record 49 of Set 8 | campo maior
# Processing Record 50 of Set 8 | tigil
# Processing Record 1 of Set 9 | touros
# City not found. Skipping...
# Processing Record 2 of Set 9 | fevralsk
# Processing Record 3 of Set 9 | tabas
# Processing Record 4 of Set 9 | belaya gora
# Processing Record 5 of Set 9 | isla vista
# Processing Record 6 of Set 9 | sechura
# Processing Record 7 of Set 9 | noumea
# Processing Record 8 of Set 9 | machiques
# Processing Record 9 of Set 9 | boyolangu
# City not found. Skipping...
# Processing Record 10 of Set 9 | malwan
# Processing Record 11 of Set 9 | tautira
# Processing Record 12 of Set 9 | moron
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | kapit
# Processing Record 15 of Set 9 | autazes
# Processing Record 16 of Set 9 | frolovo
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | khangarh
# Processing Record 19 of Set 9 | boguchany
# Processing Record 20 of Set 9 | paamiut
# Processing Record 21 of Set 9 | ustye
# Processing Record 22 of Set 9 | tuatapere
# Processing Record 23 of Set 9 | rio tercero
# Processing Record 24 of Set 9 | viedma
# Processing Record 25 of Set 9 | cuyamel
# Processing Record 26 of Set 9 | jesus maria
# City not found. Skipping...
# Processing Record 27 of Set 9 | hayato
# Processing Record 28 of Set 9 | yongan
# Processing Record 29 of Set 9 | wanxian
# Processing Record 30 of Set 9 | nawalgarh
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | grafton
# Processing Record 33 of Set 9 | avera
# Processing Record 34 of Set 9 | mercedes
# Processing Record 35 of Set 9 | peterhead
# Processing Record 36 of Set 9 | port augusta
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | gbadolite
# Processing Record 39 of Set 9 | evanston
# Processing Record 40 of Set 9 | kuytun
# Processing Record 41 of Set 9 | dunedin
# Processing Record 42 of Set 9 | poltavka
# Processing Record 43 of Set 9 | grass valley
# Processing Record 44 of Set 9 | lethem
# Processing Record 45 of Set 9 | selikhino
# Processing Record 46 of Set 9 | san borja
# Processing Record 47 of Set 9 | tuktoyaktuk
# Processing Record 48 of Set 9 | leh
# Processing Record 49 of Set 9 | namatanai
# Processing Record 50 of Set 9 | galle
# Processing Record 1 of Set 10 | shimanovsk
# Processing Record 2 of Set 10 | pasni
# Processing Record 3 of Set 10 | ginir
# Processing Record 4 of Set 10 | xining
# Processing Record 5 of Set 10 | san patricio
# Processing Record 6 of Set 10 | faanui
# Processing Record 7 of Set 10 | balkanabat
# Processing Record 8 of Set 10 | balad
# Processing Record 9 of Set 10 | hare bay
# Processing Record 10 of Set 10 | cidreira
# Processing Record 11 of Set 10 | pangnirtung
# Processing Record 12 of Set 10 | biak
# Processing Record 13 of Set 10 | pisco
# Processing Record 14 of Set 10 | isangel
# Processing Record 15 of Set 10 | beeville
# Processing Record 16 of Set 10 | saint-augustin
# Processing Record 17 of Set 10 | nchelenge
# Processing Record 18 of Set 10 | saint anthony
# Processing Record 19 of Set 10 | mount isa
# Processing Record 20 of Set 10 | samarai
# Processing Record 21 of Set 10 | hami
# Processing Record 22 of Set 10 | saldanha
# Processing Record 23 of Set 10 | shipitsyno
# Processing Record 24 of Set 10 | illintsi
# Processing Record 25 of Set 10 | santa gertrudis
# Processing Record 26 of Set 10 | yamada
# Processing Record 27 of Set 10 | antsirabe
# Processing Record 28 of Set 10 | santa cruz
# Processing Record 29 of Set 10 | beberibe
# Processing Record 30 of Set 10 | havre-saint-pierre
# Processing Record 31 of Set 10 | severnoye
# Processing Record 32 of Set 10 | inhambane
# Processing Record 33 of Set 10 | kambove
# Processing Record 34 of Set 10 | juegang
# Processing Record 35 of Set 10 | oga
# Processing Record 36 of Set 10 | tsaratanana
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | colares
# Processing Record 39 of Set 10 | nikolayevsk-na-amure
# Processing Record 40 of Set 10 | china
# Processing Record 41 of Set 10 | aginskoye
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | kachiry
# Processing Record 44 of Set 10 | ulaangom
# Processing Record 45 of Set 10 | vostok
# Processing Record 46 of Set 10 | gamba
# City not found. Skipping...
# Processing Record 47 of Set 10 | ruatoria
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | anastacio
# City not found. Skipping...
# Processing Record 50 of Set 10 | bokspits
# Processing Record 1 of Set 11 | miraflores
# Processing Record 2 of Set 11 | baghdad
# Processing Record 3 of Set 11 | castelldefels
# Processing Record 4 of Set 11 | aasiaat
# Processing Record 5 of Set 11 | guerrero negro
# Processing Record 6 of Set 11 | deputatskiy
# Processing Record 7 of Set 11 | san carlos de bariloche
# Processing Record 8 of Set 11 | aban
# Processing Record 9 of Set 11 | marondera
# Processing Record 10 of Set 11 | sabirabad
# Processing Record 11 of Set 11 | khatanga
# Processing Record 12 of Set 11 | saint-joseph
# Processing Record 13 of Set 11 | prigorodka
# Processing Record 14 of Set 11 | kuusamo
# Processing Record 15 of Set 11 | sterling
# Processing Record 16 of Set 11 | poltava
# Processing Record 17 of Set 11 | abha
# Processing Record 18 of Set 11 | ojinaga
# Processing Record 19 of Set 11 | salisbury
# Processing Record 20 of Set 11 | port hawkesbury
# Processing Record 21 of Set 11 | kununurra
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | werda
# Processing Record 24 of Set 11 | shingu
# City not found. Skipping...
# Processing Record 25 of Set 11 | macaboboni
# Processing Record 26 of Set 11 | gizo
# Processing Record 27 of Set 11 | lorengau
# Processing Record 28 of Set 11 | trelew
# Processing Record 29 of Set 11 | islamkot
# Processing Record 30 of Set 11 | salalah
# Processing Record 31 of Set 11 | beruwala
# Processing Record 32 of Set 11 | belance
# Processing Record 33 of Set 11 | bilibino
# Processing Record 34 of Set 11 | pompeia
# City not found. Skipping...
# Processing Record 35 of Set 11 | muzquiz
# Processing Record 36 of Set 11 | masuguru
# Processing Record 37 of Set 11 | pacifica
# Processing Record 38 of Set 11 | nogliki
# City not found. Skipping...
# Processing Record 39 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 40 of Set 11 | tidore
# Processing Record 41 of Set 11 | karla
# Processing Record 42 of Set 11 | isagarh
# Processing Record 43 of Set 11 | chandbali
# Processing Record 44 of Set 11 | mayo
# Processing Record 45 of Set 11 | morondava
# Processing Record 46 of Set 11 | taos
# City not found. Skipping...
# Processing Record 47 of Set 11 | ardistan
# Processing Record 48 of Set 11 | karsava
# Processing Record 49 of Set 11 | burgersdorp
# City not found. Skipping...
# Processing Record 50 of Set 11 | tabiauea
# Processing Record 1 of Set 12 | outjo
# Processing Record 2 of Set 12 | hervey bay
# Processing Record 3 of Set 12 | sayyan
# Processing Record 4 of Set 12 | cuajinicuilapa
# Processing Record 5 of Set 12 | bowen
# City not found. Skipping...
# Processing Record 6 of Set 12 | canitas
# Processing Record 7 of Set 12 | rocha
# Processing Record 8 of Set 12 | saint-louis
# Processing Record 9 of Set 12 | bemidji
# Processing Record 10 of Set 12 | klaksvik
# Processing Record 11 of Set 12 | olafsvik
# Processing Record 12 of Set 12 | oranjemund
# City not found. Skipping...
# Processing Record 13 of Set 12 | tumannyy
# Processing Record 14 of Set 12 | dong hoi
# Processing Record 15 of Set 12 | palana
# Processing Record 16 of Set 12 | novoagansk
# Processing Record 17 of Set 12 | fairbanks
# Processing Record 18 of Set 12 | camana
# Processing Record 19 of Set 12 | grao mogol
# Processing Record 20 of Set 12 | chaohu
# Processing Record 21 of Set 12 | enshi
# City not found. Skipping...
# Processing Record 22 of Set 12 | unye
# City not found. Skipping...
# Processing Record 23 of Set 12 | mizpe ramon
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | tomball
# Processing Record 26 of Set 12 | port blair
# Processing Record 27 of Set 12 | ocean city
# Processing Record 28 of Set 12 | manaus
# Processing Record 29 of Set 12 | san cristobal
# Processing Record 30 of Set 12 | nageshwari
# Processing Record 31 of Set 12 | verkhoyansk
# Processing Record 32 of Set 12 | manado
# Processing Record 33 of Set 12 | ouro preto
# City not found. Skipping...
# Processing Record 34 of Set 12 | alihe
# Processing Record 35 of Set 12 | aljezur
# Processing Record 36 of Set 12 | sistranda
# City not found. Skipping...
# Processing Record 37 of Set 12 | attawapiskat
# Processing Record 38 of Set 12 | carbonia
# Processing Record 39 of Set 12 | tortoli
# City not found. Skipping...
# Processing Record 40 of Set 12 | dzhusaly
# Processing Record 41 of Set 12 | lokosovo
# Processing Record 42 of Set 12 | besikduzu
# Processing Record 43 of Set 12 | leningradskiy
# Processing Record 44 of Set 12 | anamur
# Processing Record 45 of Set 12 | itarema
# Processing Record 46 of Set 12 | isiolo
# Processing Record 47 of Set 12 | yar-sale
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | reconquista
# Processing Record 50 of Set 12 | mpanda
# Processing Record 1 of Set 13 | bama
# Processing Record 2 of Set 13 | gander
# Processing Record 3 of Set 13 | carauari
# Processing Record 4 of Set 13 | turayf
# Processing Record 5 of Set 13 | sicuani
# Processing Record 6 of Set 13 | auki
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | ereymentau
# Processing Record 9 of Set 13 | ilulissat
# Processing Record 10 of Set 13 | muros
# Processing Record 11 of Set 13 | calvinia
# Processing Record 12 of Set 13 | naze
# Processing Record 13 of Set 13 | katangli
# Processing Record 14 of Set 13 | san policarpo
# Processing Record 15 of Set 13 | krasnovishersk
# Processing Record 16 of Set 13 | idukki
# Processing Record 17 of Set 13 | flin flon
# Processing Record 18 of Set 13 | brae
# Processing Record 19 of Set 13 | cabedelo
# Processing Record 20 of Set 13 | sivas
# Processing Record 21 of Set 13 | saint-pierre
# Processing Record 22 of Set 13 | cururupu
# Processing Record 23 of Set 13 | alexandria
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | keti bandar
# Processing Record 26 of Set 13 | brandfort
# Processing Record 27 of Set 13 | karwar
# Processing Record 28 of Set 13 | abu dhabi
# Processing Record 29 of Set 13 | mollendo
# Processing Record 30 of Set 13 | liuzhou
# Processing Record 31 of Set 13 | batemans bay
# Processing Record 32 of Set 13 | tisau
# Processing Record 33 of Set 13 | eyl
# Processing Record 34 of Set 13 | lashio
# Processing Record 35 of Set 13 | tikapur
# Processing Record 36 of Set 13 | aklavik
# Processing Record 37 of Set 13 | koungheul
# Processing Record 38 of Set 13 | ryotsu
# City not found. Skipping...
# Processing Record 39 of Set 13 | reefton
# Processing Record 40 of Set 13 | mahebourg
# Processing Record 41 of Set 13 | churapcha
# Processing Record 42 of Set 13 | aberdeen
# Processing Record 43 of Set 13 | iwanai
# Processing Record 44 of Set 13 | kurilsk
# Processing Record 45 of Set 13 | cape canaveral
# Processing Record 46 of Set 13 | tamala
# Processing Record 47 of Set 13 | bubaque
# Processing Record 48 of Set 13 | ulagan
# Processing Record 49 of Set 13 | priargunsk
# Processing Record 50 of Set 13 | kindia
# Processing Record 1 of Set 14 | kindu
# Processing Record 2 of Set 14 | teeli
# Processing Record 3 of Set 14 | umm kaddadah
# Processing Record 4 of Set 14 | vestmannaeyjar
# Processing Record 5 of Set 14 | tambun
# Processing Record 6 of Set 14 | north bend
# Processing Record 7 of Set 14 | broken hill
# Processing Record 8 of Set 14 | eyrarbakki
# Processing Record 9 of Set 14 | buraydah
# Processing Record 10 of Set 14 | platteville
# City not found. Skipping...
# Processing Record 11 of Set 14 | mergui
# Processing Record 12 of Set 14 | pirgos
# Processing Record 13 of Set 14 | temiscaming
# Processing Record 14 of Set 14 | batagay
# Processing Record 15 of Set 14 | howard springs
# Processing Record 16 of Set 14 | victor harbor
# Processing Record 17 of Set 14 | kemijarvi
# Processing Record 18 of Set 14 | ponta delgada
# Processing Record 19 of Set 14 | toktogul
# Processing Record 20 of Set 14 | sapozhok
# Processing Record 21 of Set 14 | semey
# Processing Record 22 of Set 14 | haizhou
# Processing Record 23 of Set 14 | tevriz
# Processing Record 24 of Set 14 | alta floresta
# Processing Record 25 of Set 14 | campbell river
# Processing Record 26 of Set 14 | sabang
# Processing Record 27 of Set 14 | chicama
# City not found. Skipping...
# Processing Record 28 of Set 14 | stoyba
# Processing Record 29 of Set 14 | lazaro cardenas
# Processing Record 30 of Set 14 | port moresby
# Processing Record 31 of Set 14 | springdale
# Processing Record 32 of Set 14 | manggar
# Processing Record 33 of Set 14 | kloulklubed
# Processing Record 34 of Set 14 | wilkie
# Processing Record 35 of Set 14 | panzhihua
# Processing Record 36 of Set 14 | telma
# Processing Record 37 of Set 14 | mackay
# Processing Record 38 of Set 14 | dekar
# Processing Record 39 of Set 14 | fonte boa
# Processing Record 40 of Set 14 | shubarkuduk
# Processing Record 41 of Set 14 | havelock
# Processing Record 42 of Set 14 | luganville
# Processing Record 43 of Set 14 | sarkand
# Processing Record 44 of Set 14 | uromi
# Processing Record 45 of Set 14 | lahaina
# Processing Record 46 of Set 14 | jiexiu
# Processing Record 47 of Set 14 | buckeye
# Processing Record 48 of Set 14 | surt
# Processing Record 49 of Set 14 | safranbolu
# Processing Record 50 of Set 14 | ballina
# Processing Record 1 of Set 15 | alto araguaia
# Processing Record 2 of Set 15 | wangqing
# Processing Record 3 of Set 15 | rio gallegos
# Processing Record 4 of Set 15 | mwanza
# Processing Record 5 of Set 15 | nuevo progreso
# Processing Record 6 of Set 15 | cascais
# Processing Record 7 of Set 15 | adrar
# Processing Record 8 of Set 15 | liverpool
# Processing Record 9 of Set 15 | cockburn town
# Processing Record 10 of Set 15 | srednekolymsk
# Processing Record 11 of Set 15 | sambava
# Processing Record 12 of Set 15 | ambilobe
# Processing Record 13 of Set 15 | sungaipenuh
# Processing Record 14 of Set 15 | mizdah
# City not found. Skipping...
# Processing Record 15 of Set 15 | kazalinsk
# Processing Record 16 of Set 15 | livingstonia
# Processing Record 17 of Set 15 | dhali
# Processing Record 18 of Set 15 | tigre
# Processing Record 19 of Set 15 | morant bay
# Processing Record 20 of Set 15 | okhotsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | el balyana
# Processing Record 22 of Set 15 | verkhnevilyuysk
# Processing Record 23 of Set 15 | bela
# Processing Record 24 of Set 15 | ranong
# Processing Record 25 of Set 15 | talcahuano
# Processing Record 26 of Set 15 | qasigiannguit
# Processing Record 27 of Set 15 | urusha
# Processing Record 28 of Set 15 | flagstaff
# Processing Record 29 of Set 15 | channel-port aux basques
# Processing Record 30 of Set 15 | raudeberg
# Processing Record 31 of Set 15 | mount hagen
# Processing Record 32 of Set 15 | chingirlau
# Processing Record 33 of Set 15 | fort nelson
# Processing Record 34 of Set 15 | lincoln
# Processing Record 35 of Set 15 | kuju
# Processing Record 36 of Set 15 | bereda
# Processing Record 37 of Set 15 | the valley
# City not found. Skipping...
# Processing Record 38 of Set 15 | skalistyy
# Processing Record 39 of Set 15 | kenora
# Processing Record 40 of Set 15 | cardston
# Processing Record 41 of Set 15 | smithers
# Processing Record 42 of Set 15 | dzilam gonzalez
# Processing Record 43 of Set 15 | karratha
# Processing Record 44 of Set 15 | rafaela
# Processing Record 45 of Set 15 | madang
# Processing Record 46 of Set 15 | vredendal
# Processing Record 47 of Set 15 | shache
# Processing Record 48 of Set 15 | starogard gdanski
# Processing Record 49 of Set 15 | karatuzskoye
# Processing Record 50 of Set 15 | makubetsu
# City not found. Skipping...
# Processing Record 1 of Set 16 | kankavli
# Processing Record 2 of Set 16 | rapid valley
# Processing Record 3 of Set 16 | venkatagiri
# Processing Record 4 of Set 16 | scarborough
# City not found. Skipping...
# Processing Record 5 of Set 16 | bac can
# Processing Record 6 of Set 16 | christchurch
# Processing Record 7 of Set 16 | abalak
# Processing Record 8 of Set 16 | blieskastel
# Processing Record 9 of Set 16 | nadym
# Processing Record 10 of Set 16 | anito
# Processing Record 11 of Set 16 | iztapa
# Processing Record 12 of Set 16 | totness
# Processing Record 13 of Set 16 | hofn
# Processing Record 14 of Set 16 | fereydunshahr
# Processing Record 15 of Set 16 | nanortalik
# Processing Record 16 of Set 16 | balkhash
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kodiak  57.7900 -152.4072     51.31        87          90
# 1            Kapaa  22.0752 -159.3190     82.72        79          75
# 2        Hithadhoo  -0.6000   73.0833     80.60        75          87
# 3          Rikitea -23.1203 -134.9692     70.65        67          38
# 4         Hermanus -34.4187   19.2345     61.90        53         100
# ..             ...      ...       ...       ...       ...         ...
# 705        Totness   5.8833  -56.3167     79.66        73         100
# 706           Hofn  64.2539  -15.2082     52.02        94         100
# 707  Fereydunshahr  32.9410   50.1210     67.71        21          47
# 708     Nanortalik  60.1432  -45.2371     45.12        73         100
# 709       Balkhash  46.8440   74.9804     79.83        33           5
#
#      Wind Speed Country                 Date Current Description
# 0          5.75      US  2021-07-25 20:21:42                 fog
# 1          5.01      US  2021-07-25 20:25:09          light rain
# 2          4.00      MV  2021-07-25 20:22:31          light rain
# 3          6.42      PF  2021-07-25 20:22:15    scattered clouds
# 4          9.73      ZA  2021-07-25 20:22:28     overcast clouds
# ..          ...     ...                  ...                 ...
# 705        6.71      SR  2021-07-25 20:27:11     overcast clouds
# 706       19.93      IS  2021-07-25 20:27:12     overcast clouds
# 707        4.94      IR  2021-07-25 20:27:12    scattered clouds
# 708       13.76      GL  2021-07-25 20:27:12     overcast clouds
# 709        6.91      KZ  2021-07-25 20:27:12           clear sky
#
# [710 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kodiak      US  57.7900 -152.4072     51.31        87          90
# 1            Kapaa      US  22.0752 -159.3190     82.72        79          75
# 2        Hithadhoo      MV  -0.6000   73.0833     80.60        75          87
# 3          Rikitea      PF -23.1203 -134.9692     70.65        67          38
# 4         Hermanus      ZA -34.4187   19.2345     61.90        53         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 705        Totness      SR   5.8833  -56.3167     79.66        73         100
# 706           Hofn      IS  64.2539  -15.2082     52.02        94         100
# 707  Fereydunshahr      IR  32.9410   50.1210     67.71        21          47
# 708     Nanortalik      GL  60.1432  -45.2371     45.12        73         100
# 709       Balkhash      KZ  46.8440   74.9804     79.83        33           5
#
#      Wind Speed Current Description
# 0          5.75                 fog
# 1          5.01          light rain
# 2          4.00          light rain
# 3          6.42    scattered clouds
# 4          9.73     overcast clouds
# ..          ...                 ...
# 705        6.71     overcast clouds
# 706       19.93     overcast clouds
# 707        4.94    scattered clouds
# 708       13.76     overcast clouds
# 709        6.91           clear sky
#
# [710 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
